# %%
# %pip install langchain-text-splitters langchain-openai langchain-community langchain-core langchain-cohere chromadb pypdf
# Out:
# Requirement already satisfied: langchain-text-splitters in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (0.3.11)
# Requirement already satisfied: langchain-openai in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (0.3.35)
# Requirement already satisfied: langchain-community in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (0.3.31)
# Requirement already satisfied: langchain-core in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (0.3.79)
# Requirement already satisfied: langchain-cohere in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (0.4.6)
# Requirement already satisfied: chromadb in c:\users\renan\appdata\roaming\python\python313\site-packages (1.2.2)
# Requirement already satisfied: pypdf in c:\users\renan\appdata\roaming\python\python313\site-packages (6.1.3)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\renan\appdata\roaming\python\python313\site-packages (from langchain-core) (0.4.38)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (4.14.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (2.12.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\renan\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\renan\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.11.0)
# Requirement already satisfied: certifi in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=1.104.2 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (2.6.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (0.11.1)
# Requirement already satisfied: sniffio in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\renan\appdata\roaming\python\python313\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.10.23)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\renan\appdata\roaming\python\python313\site-packages (from langchain-community) (3.13.1)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\renan\appdata\roaming\python\python313\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\renan\appdata\roaming\python\python313\site-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (2.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\renan\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\renan\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\renan\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: cohere<6.0,>=5.18.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from langchain-cohere) (5.20.0)
# Requirement already satisfied: types-pyyaml<7.0.0.0,>=6.0.12.20240917 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from langchain-cohere) (6.0.12.20250915)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (1.12.1)
# Requirement already satisfied: tokenizers<1,>=0.15 in c:\users\renan\appdata\roaming\python\python313\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (0.22.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (2.32.4.20250913)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\renan\appdata\roaming\python\python313\site-packages (from tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (0.36.0)
# Requirement already satisfied: filelock in c:\users\renan\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (2025.9.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\renan\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (4.1.2)
# Requirement already satisfied: typer>=0.9.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\renan\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\renan\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: pyproject_hooks in c:\users\renan\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\renan\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\renan\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\renan\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (0.28.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.41.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\renan\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\renan\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\renan\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\renan\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\renan\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\renan\appdata\roaming\python\python313\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.71.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.59b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\renan\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\renan\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\renan\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\renan\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\renan\appdata\roaming\python\python313\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\renan\appdata\roaming\python\python313\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\renan\appdata\roaming\python\python313\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import Chroma
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough, RunnableParallel
from langchain_core.output_parsers import StrOutputParser

from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_cohere import CohereRerank

import os

# %%
os.environ["OPENAI_API_KEY"] = "your_openai_api_key_here"  # Substitua pela sua chave da OpenAI

# %%
os.environ["COHERE_API_KEY"] = "your_cohere_api_key_here"  # Substitua pela sua chave da Cohere

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

llm = ChatOpenAI(model="gpt-4o", max_tokens=600)

# %%
pdf_link = "os-sertoes.pdf"

loader = PyPDFLoader(pdf_link, extract_images=False)

pages = loader.load_and_split()

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=4000,
    chunk_overlap=200,
    length_function=len,
    add_start_index=True
)

chuncks = text_splitter.split_documents(pages)

# %%
# Criar vector store
vectordb = Chroma(embedding_function=embeddings)


batch_size = 20  # Processar 20 chunks por vez
total_chunks = len(chuncks)

for i in range(0, total_chunks, batch_size):
    batch = chuncks[i:i + batch_size]
    vectordb.add_documents(batch)
    print(f"  ✓ Processados {min(i + batch_size, total_chunks)}/{total_chunks} chunks")



# Criar retriever "naive" que busca 10 documentos
naive_retriever = vectordb.as_retriever(search_kwargs={"k": 10})
# Out:
#   ✓ Processados 20/658 chunks
#   ✓ Processados 40/658 chunks
#   ✓ Processados 40/658 chunks
#   ✓ Processados 60/658 chunks
#   ✓ Processados 60/658 chunks
#   ✓ Processados 80/658 chunks
#   ✓ Processados 80/658 chunks
#   ✓ Processados 100/658 chunks
#   ✓ Processados 100/658 chunks
#   ✓ Processados 120/658 chunks
#   ✓ Processados 120/658 chunks
#   ✓ Processados 140/658 chunks
#   ✓ Processados 140/658 chunks
#   ✓ Processados 160/658 chunks
#   ✓ Processados 160/658 chunks
#   ✓ Processados 180/658 chunks
#   ✓ Processados 180/658 chunks
#   ✓ Processados 200/658 chunks
#   ✓ Processados 200/658 chunks
#   ✓ Processados 220/658 chunks
#   ✓ Processados 220/658 chunks
#   ✓ Processados 240/658 chunks
#   ✓ Processados 240/658 chunks
#   ✓ Processados 260/658 chunks
#   ✓ Processados 260/658 chunks
#   ✓ Processados 280/658 chunks
#   ✓ Processados 280/658 chunks
#   ✓ Processados 300/658 chunks
#   ✓ Processados 300/658 chunks
#   ✓ Processados 320/658 chunks
#   ✓ Processados 320/658 chunks
#   ✓ Processados 340/658 chunks
#   ✓ Processados 340/658 chunks
#   ✓ Processados 360/658 chunks
#   ✓ Processados 360/658 chunks
#   ✓ Processados 380/658 chunks
#   ✓ Processados 380/658 chunks
#   ✓ Processados 400/658 chunks
#   ✓ Processados 400/658 chunks
#   ✓ Processados 420/658 chunks
#   ✓ Processados 420/658 chunks
#   ✓ Processados 440/658 chunks
#   ✓ Processados 440/658 chunks
#   ✓ Processados 460/658 chunks
#   ✓ Processados 460/658 chunks
#   ✓ Processados 480/658 chunks
#   ✓ Processados 480/658 chunks
#   ✓ Processados 500/658 chunks
#   ✓ Processados 500/658 chunks
#   ✓ Processados 520/658 chunks
#   ✓ Processados 520/658 chunks
#   ✓ Processados 540/658 chunks
#   ✓ Processados 540/658 chunks
#   ✓ Processados 560/658 chunks
#   ✓ Processados 560/658 chunks
#   ✓ Processados 580/658 chunks
#   ✓ Processados 580/658 chunks
#   ✓ Processados 600/658 chunks
#   ✓ Processados 600/658 chunks
#   ✓ Processados 620/658 chunks
#   ✓ Processados 620/658 chunks
#   ✓ Processados 640/658 chunks
#   ✓ Processados 640/658 chunks
#   ✓ Processados 658/658 chunks
#   ✓ Processados 658/658 chunks

# %%
# Criar o Cohere Rerank compressor
# top_n=3 significa que vai retornar apenas os 3 documentos mais relevantes dos 10 buscados
rerank = CohereRerank(model="rerank-v3.5", top_n=3)

# Criar o Compression Retriever com Rerank
compression_retriever = ContextualCompressionRetriever(
    base_retriever=naive_retriever,  # Retriever que busca 10 documentos
    base_compressor=rerank            # Rerank que seleciona os 3 melhores
)

# %%
TEMPLATE = """
Você é um especialista em literatura brasileira. Responda a pergunta abaixo utilizando o contexto informado

Contexto: {context}
    
Pergunta: {question}
"""

prompt = ChatPromptTemplate.from_template(TEMPLATE)

# %%
# Função auxiliar para formatar documentos
def format_docs(docs):
    return "\n\n".join([doc.page_content for doc in docs])

# Criar a chain RAG com Compression Retriever (Rerank)
setup_retrieval = RunnableParallel(
    {
        "question": RunnablePassthrough(),
        "context": compression_retriever | format_docs
    }
)

output_parser = StrOutputParser()

# Montar a chain completa
rerank_rag_chain = setup_retrieval | prompt | llm | output_parser

# %%
questions = [
    "Qual é a visão de Euclides da Cunha sobre o ambiente natural do sertão nordestino e como ele influencia a vida dos habitantes?",
    "Quais são as principais características da população sertaneja descritas por Euclides da Cunha? Como ele relaciona essas características com o ambiente em que vivem?",
    "Qual foi o contexto histórico e político que levou à Guerra de Canudos, segundo Euclides da Cunha?",
    "Como Euclides da Cunha descreve a figura de Antônio Conselheiro e seu papel na Guerra de Canudos?",
    "Quais são os principais aspectos da crítica social e política presentes em \"Os Sertões\"? Como esses aspectos refletem a visão do autor sobre o Brasil da época?",
]

# %%
def answer_question(question):
    return rerank_rag_chain.invoke(question)

# %%
# Responder todas as 5 perguntas da lista

for index, question in enumerate(questions, 1):
    try:
        print("=" * 80)
        print(f"PERGUNTA {index}/5:")
        print(question)
        print("=" * 80)

        resposta = answer_question(question)

        print(f"\nRESPOSTA:")
        print(resposta)
        print("\n" + "=" * 80 + "\n")

    except Exception as e:
        print(question)
        print("=" * 80)
        
        resposta = rerank_rag_chain.invoke(question)
        
        print(f"\nRESPOSTA:")
        print(resposta)
        print("\n" + "=" * 80 + "\n")
        
    except Exception as e:
        print(f"❌ Erro ao processar pergunta {index}: {e}\n")
        continue
# Out:
# ================================================================================
# PERGUNTA 1/5:
# Qual é a visão de Euclides da Cunha sobre o ambiente natural do sertão nordestino e como ele influencia a vida dos habitantes?
# ================================================================================
#
# RESPOSTA:
# Euclides da Cunha, em "Os Sertões", descreve o sertão nordestino como um ambiente de extremos e contradições. Ele vê o sertão como um "vale fértil" em momentos de chuva, um grande "pomar sem dono", mas que se transforma drasticamente com a chegada do período de seca, assumindo uma atmosfera "asfixiante" e um solo "empedrado" que impõe um "espasmo assombrador". Essa visão enfatiza a natureza antitética da região, com ciclos de abundância e escassez.
#
# Para Euclides, a seca não é apenas uma questão de falta d'água a ser resolvida por meios locais, como cisternas ou poços artesianos. Ele entende que o verdadeiro desafio é o combate a um "deserto" mais amplo, que afeta profundamente a "economia geral da Vida". Assim, a seca é vista como uma manifestação do "martírio secular da Terra", o que reflete um ciclo mais amplo de sofrimento humano e ecológico.
#
# A influência dessas condições extremas na vida dos habitantes é marcante. O sertanejo é descrito como alguém que vive em constante luta contra o seu ambiente hostil. O sofrimento dos habitantes do sertão é, assim, um reflexo direto das dificuldades impostas pela terra em que vivem. Euclides mistura essa análise com uma crítica socioeconômica, articulando como as condições naturais extremas contribuem para a perpetuação dos deserdados da fortuna, simbolizados nos sertanejos nordestinos.
#
# Ao longo de "Os Sertões", Euclides combina elementos do Naturalismo e Positivismo, empregando um estilo vibrante e colorido, para expressar suas análises sobre a interação entre a terra, o homem e seus desafios, destacando as limitações das explicações científicas tradicionais em captar a complexidade e a resiliência do sertanejo diante de um ambiente tão inóspito e imprevisível.
#
# ================================================================================
#
# ================================================================================
# PERGUNTA 2/5:
# Quais são as principais características da população sertaneja descritas por Euclides da Cunha? Como ele relaciona essas características com o ambiente em que vivem?
# ================================================================================
#
# RESPOSTA:
# Euclides da Cunha, em "Os Sertões", descreve o sertão nordestino como um ambiente de extremos e contradições. Ele vê o sertão como um "vale fértil" em momentos de chuva, um grande "pomar sem dono", mas que se transforma drasticamente com a chegada do período de seca, assumindo uma atmosfera "asfixiante" e um solo "empedrado" que impõe um "espasmo assombrador". Essa visão enfatiza a natureza antitética da região, com ciclos de abundância e escassez.
#
# Para Euclides, a seca não é apenas uma questão de falta d'água a ser resolvida por meios locais, como cisternas ou poços artesianos. Ele entende que o verdadeiro desafio é o combate a um "deserto" mais amplo, que afeta profundamente a "economia geral da Vida". Assim, a seca é vista como uma manifestação do "martírio secular da Terra", o que reflete um ciclo mais amplo de sofrimento humano e ecológico.
#
# A influência dessas condições extremas na vida dos habitantes é marcante. O sertanejo é descrito como alguém que vive em constante luta contra o seu ambiente hostil. O sofrimento dos habitantes do sertão é, assim, um reflexo direto das dificuldades impostas pela terra em que vivem. Euclides mistura essa análise com uma crítica socioeconômica, articulando como as condições naturais extremas contribuem para a perpetuação dos deserdados da fortuna, simbolizados nos sertanejos nordestinos.
#
# Ao longo de "Os Sertões", Euclides combina elementos do Naturalismo e Positivismo, empregando um estilo vibrante e colorido, para expressar suas análises sobre a interação entre a terra, o homem e seus desafios, destacando as limitações das explicações científicas tradicionais em captar a complexidade e a resiliência do sertanejo diante de um ambiente tão inóspito e imprevisível.
#
# ================================================================================
#
# ================================================================================
# PERGUNTA 2/5:
# Quais são as principais características da população sertaneja descritas por Euclides da Cunha? Como ele relaciona essas características com o ambiente em que vivem?
# ================================================================================
#
# RESPOSTA:
# Euclides da Cunha descreve a população sertaneja como um grupo que desenvolveu uma fisionomia própria e distinta devido a vários fatores históricos e ambientais. Algumas das principais características dessa população, conforme descrito em "Os Sertões", incluem:
#
# 1. **Mestiçagem Generalizada**: A população sertaneja é resultado de uma extensa mestiçagem, caracterizada pela mistura de brancos, negros, indígenas e outras etnias. Essa diversidade racial resulta em uma grande variedade de características físicas e culturais, mas gradualmente, à medida que se penetra mais profundamente nos sertões, há uma maior homogeneidade.
#
# 2. **Isolamento Cultural e Geográfico**: Os sertanejos evoluíram cultural e socialmente de maneira isolada, distantes das influências das cidades do litoral e das zonas intensamente colonizadas. Esse isolamento é reforçado por barreiras naturais e políticas, como a carta régia de 1701, que proibiu comunicações entre os sertões e o sul do Brasil.
#
# 3. **Adaptação ao Meio Hostil**: Os sertanejos se adaptaram ao meio agressivo dos sertões, com sua "flora agressiva", clima severo, secas periódicas e solo estéril. Este ambiente hostil forjou um povo resistente e tenaz, assemelhado à "rocha viva", uma metáfora que Euclides usa para descrever a essência dura e inabalável do sertanejo.
#
# 4. **Vida Pastoril**: A vida nos sertões é grandemente pastoril. Os sertanejos, como os vaqueiros, se dedicam principalmente à criação de gado e se identificam com essa forma de vida, que contribuiu para moldar sua identidade cultural.
#
# 5. **Divórcio das Gentes do Sul**: Afastados das gentes do sul e das influências coloniais mais diretas, os sertanejos desenvolveram uma sociedade com características próprias, quase como se vivessem em um país distinto dentro do próprio Brasil.
#
# Euclides da Cunha relaciona essas características diretamente ao ambiente em que vivem. Ele acredita que o meio físico é um elemento fundamental na formação do caráter do sertanejo. A adversidade dos sertões, com sua geografia inóspita e clima rigoroso, é vista como um fator que molda um povo resiliente, adaptável e forte. Os sertanejos são representados como produtos de seu meio, ilustrando a interseção entre a geografia física e a genealogia cultural.
#
# ================================================================================
#
# ================================================================================
# PERGUNTA 3/5:
# Qual foi o contexto histórico e político que levou à Guerra de Canudos, segundo Euclides da Cunha?
# ================================================================================
#
# RESPOSTA:
# Euclides da Cunha descreve a população sertaneja como um grupo que desenvolveu uma fisionomia própria e distinta devido a vários fatores históricos e ambientais. Algumas das principais características dessa população, conforme descrito em "Os Sertões", incluem:
#
# 1. **Mestiçagem Generalizada**: A população sertaneja é resultado de uma extensa mestiçagem, caracterizada pela mistura de brancos, negros, indígenas e outras etnias. Essa diversidade racial resulta em uma grande variedade de características físicas e culturais, mas gradualmente, à medida que se penetra mais profundamente nos sertões, há uma maior homogeneidade.
#
# 2. **Isolamento Cultural e Geográfico**: Os sertanejos evoluíram cultural e socialmente de maneira isolada, distantes das influências das cidades do litoral e das zonas intensamente colonizadas. Esse isolamento é reforçado por barreiras naturais e políticas, como a carta régia de 1701, que proibiu comunicações entre os sertões e o sul do Brasil.
#
# 3. **Adaptação ao Meio Hostil**: Os sertanejos se adaptaram ao meio agressivo dos sertões, com sua "flora agressiva", clima severo, secas periódicas e solo estéril. Este ambiente hostil forjou um povo resistente e tenaz, assemelhado à "rocha viva", uma metáfora que Euclides usa para descrever a essência dura e inabalável do sertanejo.
#
#
# 3. **Crítica à Política Brasileira**: A obra não poupa críticas ao governo republicano e suas políticas, que falharam em compreender e integrar os sertanejos ao projeto de nação. Euclides denuncia a negligência e a miopia das elites políticas, incapazes de ver a complexidade e a humanidade dos habitantes do sertão.
#
# 4. **Influência do Positivismo e do Naturalismo**: Euclides utiliza referenciais científicos e filosóficos contemporâneos, como as teorias de raça, meio e momento de Hippolyte Taine, para estruturar sua análise, embora essa abordagem tenha gerado críticas por possíveis imprecisões científicas. No entanto, as bases naturalistas e positivistas reforçam seu desejo de compreender e expor a realidade nordestina de maneira objetiva.
#
# 5. **Transformações Sociais**: A narrativa está situada em um contexto de grande transformação política e social no Brasil, incluindo o processo de Abolição da Escravatura, o estabelecimento da República e as influências da Guerra do Paraguai. A obra reflete o impacto dessas mudanças no sertão e a resistência das comunidades locais frente a elas.
#
# Os aspectos críticos de "Os Sertões" revelam um Brasil em transição, marcado por profundas desigualdades e tensões entre o litoral e o interior. A obra de Euclides da Cunha é uma tentativa de dar voz aos deserdados da fortuna e de
#
# ================================================================================
#
#
# RESPOSTA:
# "Os Sertões" de Euclides da Cunha é uma obra que contém uma crítica social e política incisiva, refletindo a visão do autor sobre o Brasil do final do século XIX. A narrativa se desdobra em três partes: "A Terra," "O Homem" e "A Luta," cada uma abordando diferentes facetas da realidade brasileira.
#
# 1. **Crítica à Desigualdade Social**: Euclides apresenta uma crítica forte à desigualdade social e à forma como o sertanejo nordestino é marginalizado e visto como primitivo frente à sociedade litorânea "civilizada". Araripe Júnior, um crítico da época, por exemplo, expressa um ponto de vista que reflete o preconceito da época: o sertanejo como parte de uma barbárie oposta à civilização. Euclides desafia essa visão ao retratar os sertanejos com uma dignidade inerente, simbolizando-os como "a rocha viva da nossa raça".
#
# 2. **Conflito Civilização vs. Barbárie**: Esse é um tema central em "Os Sertões". Euclides subverte a dicotomia entre civilização e barbárie ao evidenciar as "selvatiquezas" cometidas em nome da civilização pelas tropas republicanas na Guerra de Canudos. A guerra é vista como um ataque aos sertanejos, que são brutalmente reprimidos, mesmo quando defendem suas formas de vida.
#
# 3. **Crítica à Política Brasileira**: A obra não poupa críticas ao governo republicano e suas políticas, que falharam em compreender e integrar os sertanejos ao projeto de nação. Euclides denuncia a negligência e a miopia das elites políticas, incapazes de ver a complexidade e a humanidade dos habitantes do sertão.
#
# 4. **Influência do Positivismo e do Naturalismo**: Euclides utiliza referenciais científicos e filosóficos contemporâneos, como as teorias de raça, meio e momento de Hippolyte Taine, para estruturar sua análise, embora essa abordagem tenha gerado críticas por possíveis imprecisões científicas. No entanto, as bases naturalistas e positivistas reforçam seu desejo de compreender e expor a realidade nordestina de maneira objetiva.
#
# 5. **Transformações Sociais**: A narrativa está situada em um contexto de grande transformação política e social no Brasil, incluindo o processo de Abolição da Escravatura, o estabelecimento da República e as influências da Guerra do Paraguai. A obra reflete o impacto dessas mudanças no sertão e a resistência das comunidades locais frente a elas.
#
# Os aspectos críticos de "Os Sertões" revelam um Brasil em transição, marcado por profundas desigualdades e tensões entre o litoral e o interior. A obra de Euclides da Cunha é uma tentativa de dar voz aos deserdados da fortuna e de
#
# ================================================================================
